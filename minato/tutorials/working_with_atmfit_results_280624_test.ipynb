# %% [markdown]
# # Read results from Atmfit

# %% [markdown]
# Now we will use `read_results` to work with the feather file

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('/Users/villasenor/science/github/jvillasr/MINATO')
from minato import read_results as rr
import importlib
importlib.reload(rr)
# Out:
# <module 'minato.read_results' from '/Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py'>

# %% [markdown]
# First we load the feather table

# %%
data = 'atmfit_results_290624_test.feather'
df = pd.read_feather(data)
display(df)
# Out:
#         lr     TA   gA  mA  vA     TB   gB  mB  vB  chi2_tot     chi2A  \
# 0     0.25  15000  210   5  40  15000  250   5  40  2.978022  1.142374
# 1     0.25  15000  210   5  40  15000  250   9  40  3.261555  1.142374
# 2     0.25  15000  210   5  40  20000  250   5  40  3.687650  1.142374
# 3     0.25  15000  210   5  40  20000  250   9  40  3.991940  1.142374
# 4     0.25  15000  210   5  40  20000  270   5  40  3.425924  1.142374
# ...    ...    ...  ...  ..  ..    ...  ...  ..  ..       ...       ...
# 9235  0.45  30000  350  25  40  30000  310   9  40  7.902666  5.139937
# 9236  0.45  30000  350  25  40  30000  330   5  40  7.345322  5.139937
# 9237  0.45  30000  350  25  40  30000  330   9  40  7.774932  5.139937
# 9238  0.45  30000  350  25  40  30000  350   5  40  7.234764  5.139937
# 9239  0.45  30000  350  25  40  30000  350   9  40  7.639220  5.139937
#
#          chi2B  chi2r_tot  chi2redA  chi2redB  ndata
# 0     1.835648   0.002872  0.001001  0.001871   2140
# 1     2.119181   0.003161  0.001001  0.002160   2140
# 2     2.545276   0.003596  0.001001  0.002595   2140
# 3     2.849566   0.003906  0.001001  0.002905   2140
# 4     2.283550   0.003329  0.001001  0.002328   2140
# ...        ...        ...       ...       ...    ...
# 9235  2.762729   0.007321  0.004505  0.002816   2140
# 9236  2.205385   0.006753  0.004505  0.002248   2140
# 9237  2.634996   0.007191  0.004505  0.002686   2140
# 9238  2.094828   0.006640  0.004505  0.002135   2140
# 9239  2.499283   0.007052  0.004505  0.002548   2140
#
# [9240 rows x 16 columns]

# %% [markdown]
# And now we use `compute_bestfit` to get a nice plot of the minimum $\chi^2$ for each parameter, and the respective 1-$\sigma$ uncertainties. For 2-$\sigma$ uncertainties use `cl=0.95`
#
# First, `compute_bestfit` will show us some information about the $\chi^2$ values, including a histogram. The second step is to get the minimum $\chi^2$ value for each value in the grid, which are printed on the cell output, and then it fits these points, in this case with a polinomial. If you have quite symmetric $\chi^2$ values, you can try `fit_type='parab'`. Finally, you get the plot, which you can save by specifying a save path `save_to='path+filename.extension'`

# %%
rr.compute_bestfit(df, fit_type='poly', chi2max=5000, save_to='./errors_plot_test.png')
# Out:
# Index(['lr', 'TA', 'gA', 'mA', 'vA', 'TB', 'gB', 'mB', 'vB', 'chi2_tot',
#        'chi2A', 'chi2B', 'chi2r_tot', 'chi2redA', 'chi2redB', 'ndata'],
#       dtype='object')
# min unscaled chi2 value = 2.676336592350851
# max unscaled chi2 value = 9.731616749145454
# min scaled chi2 value = 2124.0
# max scaled chi2 value = 7723.226605450546
# dof = 2124
# 68.0% confidence level = 2153.956844026424
# lr
# [0.25, 0.3, 0.35, 0.4, 0.45]
# [2272.1764231255247, 2168.94764016664, 2124.0, 2141.912234947246, 2274.838784915828]
# TA
# [15.0, 20.0, 25.0, 30.0]
# [2124.0, 2658.1601495534806, 2729.6212983428327, 2874.206892460941]
# gA
# [2.1, 2.3, 2.5, 2.7, 2.9, 3.1, 3.3, 3.5]
# [2258.944563867119, 2124.0, 2141.912234947246, 2748.3384376896884, 2658.1601495534806, 2729.6212983428327, 2733.611552816936, 2874.206892460941]
# mA
# [5, 9, 13, 17, 21, 25]
# [2124.0, 2312.2428505938888, 2587.390577353953, 2881.628170985747, 3210.448543832442, 3502.4241016303627]
# vA
# Too few values to interpolate.
# [40]
# nan
# TB
# [15.0, 20.0, 25.0, 30.0]
# [2299.8253250960893, 2340.1665430511134, 2124.0, 2238.2662787911977]
# gB
# [2.5, 2.7, 2.9, 3.1, 3.3, 3.5]
# [2299.8253250960893, 2146.7873246028353, 2124.0, 2145.922147475911, 2168.94764016664, 2238.2662787911977]
# mB
# Too few values to interpolate.
# [5, 9]
# nan
# vB
# Too few values to interpolate.
# [40]
# nan
# pars_min =  [[[0.25, 0.3, 0.35, 0.4, 0.45], [2272.1764231255247, 2168.94764016664, 2124.0, 2141.912234947246, 2274.838784915828]], [[15.0, 20.0, 25.0, 30.0], [2124.0, 2658.1601495534806, 2729.6212983428327, 2874.206892460941]], [[2.1, 2.3, 2.5, 2.7, 2.9, 3.1, 3.3, 3.5], [2258.944563867119, 2124.0, 2141.912234947246, 2748.3384376896884, 2658.1601495534806, 2729.6212983428327, 2733.611552816936, 2874.206892460941]], [[5, 9, 13, 17, 21, 25], [2124.0, 2312.2428505938888, 2587.390577353953, 2881.628170985747, 3210.448543832442, 3502.4241016303627]], [[40], nan], [[15.0, 20.0, 25.0, 30.0], [2299.8253250960893, 2340.1665430511134, 2124.0, 2238.2662787911977]], [[2.5, 2.7, 2.9, 3.1, 3.3, 3.5], [2299.8253250960893, 2146.7873246028353, 2124.0, 2145.922147475911, 2168.94764016664, 2238.2662787911977]], [[5, 9], nan], [[40], nan]]
#
# Fitting polynomial to parameter:
#    lr
#        [0.25, 0.3, 0.35, 0.4, 0.45] [2272.1764231255247, 2168.94764016664, 2124.0, 2141.912234947246, 2274.838784915828]
#    TA
#        [15.0, 20.0, 25.0, 30.0] [2124.0, 2658.1601495534806, 2729.6212983428327, 2874.206892460941]
#    gA
#        [2.1, 2.3, 2.5, 2.7, 2.9, 3.1, 3.3, 3.5] [2258.944563867119, 2124.0, 2141.912234947246, 2748.3384376896884, 2658.1601495534806, 2729.6212983428327, 2733.611552816936, 2874.206892460941]
#    mA
#        [5, 9, 13, 17, 21, 25] [2124.0, 2312.2428505938888, 2587.390577353953, 2881.628170985747, 3210.448543832442, 3502.4241016303627]
#    vA
#        [40] nan
# Insufficient data points for fitting.
# Failed to fit polynomial for parameter vA
#    TB
#        [15.0, 20.0, 25.0, 30.0] [2299.8253250960893, 2340.1665430511134, 2124.0, 2238.2662787911977]
#    gB
#        [2.5, 2.7, 2.9, 3.1, 3.3, 3.5] [2299.8253250960893, 2146.7873246028353, 2124.0, 2145.922147475911, 2168.94764016664, 2238.2662787911977]
#    mB
#        [5, 9] nan
# Insufficient data points for fitting.
# Failed to fit polynomial for parameter mB
#    vB
#        [40] nan
# Insufficient data points for fitting.
# Failed to fit polynomial for parameter vB
#
# Making plot
# Only one error determined
# Only one error determined
# /Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py:682: RankWarning: Polyfit may be poorly conditioned
#   coefs = [np.polyfit(x, y, deg=i) for i in range(1, max_degree+1)]
# /Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py:682: RankWarning: Polyfit may be poorly conditioned
#   coefs = [np.polyfit(x, y, deg=i) for i in range(1, max_degree+1)]
# /Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py:682: RankWarning: Polyfit may be poorly conditioned
#   coefs = [np.polyfit(x, y, deg=i) for i in range(1, max_degree+1)]
# /Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py:682: RankWarning: Polyfit may be poorly conditioned
#   coefs = [np.polyfit(x, y, deg=i) for i in range(1, max_degree+1)]

# %% [markdown]
# # 2D $\chi^2$ map

# %% [markdown]
# It can be useful to plot the 2D $\chi^2$ map to look for correlations and degeneracies.<br>
# For this we need to bring back the grid we constructed for the `span_example` tutorial, and we'll put it in a dictionary

# %%
teffA = np.linspace(10, 15, 6, dtype=int)
loggA = [20, 22, 24, 26, 28]
rotA = list(range(20, 70, 10))
teffB = [22, 24, 26, 28, 30, 32.5]
loggB = [25, 30, 35, 40]
# rotB = list(range(0, 600, 100))
rotB = [200]
lrat = np.linspace(30, 45, 4)/100
he2h = np.linspace(8, 12, 5)/100
pars_dic = {'lrat':lrat, 'He2H':he2h, 'rotB':rotB, 'loggB':loggB, 'teffB':teffB, 'rotA':rotA, 'loggA':loggA, 'teffA':teffA}

# %% [markdown]
# It's important to rename the $\chi^2$ column to 'chi2' so that the code can pick the correct column

# %%
df.rename(columns={'chi2_tot': 'chi2'}, inplace=True)

# %% [markdown]
# We'll do the plot using `plot_corr`. One of the parameters we'll use here is `rot_labels` to rotate the tick labels that are too long.<br> We need the number of the bottom panels where we want to apply the rotation, this number increases to the right and from top to bottom, so in our case we want panels 45 and 47.

# %% [markdown]
# The parameter `vmax` is also useful since it will allows to adapt the maximum value in the color map.<br>
# The histogram at the beginning of this tutorial can be helpful for this.

# %% [markdown]
# Setting `clabels='sigma'` will plot $\sigma$ labels to the contours. `clabels='numeric'` can also be used to show numeric values.

# %%
rotate = [45, 47]
rr.plot_corr(df, pars_dic, vmax=1.6, rot_labels=rotate, clabels='sigma')

# %% [markdown]
# To see how to plot the best-fitting models found in this tutorial, see the **plot_model** tutorial
