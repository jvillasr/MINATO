# %% [markdown]
# # Read results from Atmfit

# %% [markdown]
# Now we will use `read_results` to work with the feather file

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('/Users/villasenor/science/github/jvillasr/MINATO')
from minato import read_results as rr
import importlib
importlib.reload(rr)
# Out:
# <module 'minato.read_results' from '/Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py'>

# %% [markdown]
# First we load the feather table

# %%
data = 'atmfit_results_280624_test.feather'
df = pd.read_feather(data)
display(df)
# Out:
#         lr     TA   gA  mA  vA     TB   gB  mB  vB   chi2_tot     chi2A  \
# 0     0.05  15000  210   5  40  15000  250   5  40  82.453610  1.807956
# 1     0.05  15000  210   5  40  15000  250   9  40  82.154997  1.807956
# 2     0.05  15000  210   5  40  20000  250   5  40  89.405148  1.807956
# 3     0.05  15000  210   5  40  20000  250   9  40  88.400464  1.807956
# 4     0.05  15000  210   5  40  20000  270   5  40  86.033134  1.807956
# ...    ...    ...  ...  ..  ..    ...  ...  ..  ..        ...       ...
# 9235  0.25  30000  350  25  40  30000  310   9  40   7.865818  4.464497
# 9236  0.25  30000  350  25  40  30000  330   5  40   6.900874  4.464497
# 9237  0.25  30000  350  25  40  30000  330   9  40   7.198963  4.464497
# 9238  0.25  30000  350  25  40  30000  350   5  40   6.423651  4.464497
# 9239  0.25  30000  350  25  40  30000  350   9  40   6.689355  4.464497
#
#           chi2B  chi2r_tot  chi2redA  chi2redB  ndata
# 0     80.645654   0.083792  0.001585  0.082208   2140
# 1     80.347040   0.083488  0.001585  0.081903   2140
# 2     87.597191   0.090878  0.001585  0.089294   2140
# 3     86.592507   0.089854  0.001585  0.088270   2140
# 4     84.225178   0.087441  0.001585  0.085856   2140
# ...         ...        ...       ...       ...    ...
# 9235   3.401321   0.007380  0.003913  0.003467   2140
# 9236   2.436377   0.006396  0.003913  0.002484   2140
# 9237   2.734466   0.006700  0.003913  0.002787   2140
# 9238   1.959154   0.005910  0.003913  0.001997   2140
# 9239   2.224859   0.006181  0.003913  0.002268   2140
#
# [9240 rows x 16 columns]

# %% [markdown]
# And now we use `compute_bestfit` to get a nice plot of the minimum $\chi^2$ for each parameter, and the respective 1-$\sigma$ uncertainties. For 2-$\sigma$ uncertainties use `cl=0.95`
#
# First, `compute_bestfit` will show us some information about the $\chi^2$ values, including a histogram. The second step is to get the minimum $\chi^2$ value for each value in the grid, which are printed on the cell output, and then it fits these points, in this case with a polinomial. If you have quite symmetric $\chi^2$ values, you can try `fit_type='parab'`. Finally, you get the plot, which you can save by specifying a save path `save_to='path+filename.extension'`

# %%
rr.compute_bestfit(df, fit_type='poly', chi2max=5000, save_to='./errors_plot_test.png')
# Out:
# Index(['lr', 'TA', 'gA', 'mA', 'vA', 'TB', 'gB', 'mB', 'vB', 'chi2_tot',
#        'chi2A', 'chi2B', 'chi2r_tot', 'chi2redA', 'chi2redB', 'ndata'],
#       dtype='object')
# min unscaled chi2 value = 2.863045624052595
# max unscaled chi2 value = 98.28573871654461
# min scaled chi2 value = 2124.0
# max scaled chi2 value = 72914.97811985471
# dof = 2124
# 68.0% confidence level = 2153.956844026424
# lr
# [0.05, 0.1, 0.15, 0.2, 0.25]
# [60517.62561198404, 11233.417743044309, 4323.028773763205, 2595.9189736113185, 2124.0]
# TA
# [15000, 20000, 25000, 30000]
# [2124.0, 2580.9145638844825, 2551.613324860156, 2686.7699961385365]
# gA
# [210, 230, 250, 270, 290, 310, 330, 350]
# [2124.0, 2220.189471366162, 2626.8419564986134, 2580.9145638844825, 2583.382209221457, 2551.613324860156, 2599.639276311488, 2686.7699961385365]
# mA
# [5, 9, 13, 17, 21, 25]
# [2124.0, 2329.697576505799, 2659.7456115679515, 3102.4597415861867, 3595.1304157155473, 4051.3277172022554]
# vA
# Too few values to interpolate.
# [40]
# nan
# TB
# [15000, 20000, 25000, 30000]
# [2209.2972949813156, 2400.5850005080865, 2124.0, 2300.922289940503]
# gB
# [250, 270, 290, 310, 330, 350]
# [2209.2972949813156, 2541.5810617617635, 2400.5850005080865, 2223.4793094775005, 2124.0, 2300.922289940503]
# mB
# Too few values to interpolate.
# [5, 9]
# nan
# vB
# Too few values to interpolate.
# [40]
# nan
# pars_min =  [[[0.05, 0.1, 0.15, 0.2, 0.25], [60517.62561198404, 11233.417743044309, 4323.028773763205, 2595.9189736113185, 2124.0]], [[15000, 20000, 25000, 30000], [2124.0, 2580.9145638844825, 2551.613324860156, 2686.7699961385365]], [[210, 230, 250, 270, 290, 310, 330, 350], [2124.0, 2220.189471366162, 2626.8419564986134, 2580.9145638844825, 2583.382209221457, 2551.613324860156, 2599.639276311488, 2686.7699961385365]], [[5, 9, 13, 17, 21, 25], [2124.0, 2329.697576505799, 2659.7456115679515, 3102.4597415861867, 3595.1304157155473, 4051.3277172022554]], [[40], nan], [[15000, 20000, 25000, 30000], [2209.2972949813156, 2400.5850005080865, 2124.0, 2300.922289940503]], [[250, 270, 290, 310, 330, 350], [2209.2972949813156, 2541.5810617617635, 2400.5850005080865, 2223.4793094775005, 2124.0, 2300.922289940503]], [[5, 9], nan], [[40], nan]]
#
# Fitting polynomial to parameter:
#    lr
#        [0.05, 0.1, 0.15, 0.2, 0.25] [60517.62561198404, 11233.417743044309, 4323.028773763205, 2595.9189736113185, 2124.0]
#    TA
#        [15000, 20000, 25000, 30000] [2124.0, 2580.9145638844825, 2551.613324860156, 2686.7699961385365]
#    gA
#        [210, 230, 250, 270, 290, 310, 330, 350] [2124.0, 2220.189471366162, 2626.8419564986134, 2580.9145638844825, 2583.382209221457, 2551.613324860156, 2599.639276311488, 2686.7699961385365]
#    mA
#        [5, 9, 13, 17, 21, 25] [2124.0, 2329.697576505799, 2659.7456115679515, 3102.4597415861867, 3595.1304157155473, 4051.3277172022554]
#    vA
#        [40] nan
# Insufficient data points for fitting.
# Failed to fit polynomial for parameter vA
#    TB
#        [15000, 20000, 25000, 30000] [2209.2972949813156, 2400.5850005080865, 2124.0, 2300.922289940503]
#    gB
#        [250, 270, 290, 310, 330, 350] [2209.2972949813156, 2541.5810617617635, 2400.5850005080865, 2223.4793094775005, 2124.0, 2300.922289940503]
#    mB
#        [5, 9] nan
# Insufficient data points for fitting.
# Failed to fit polynomial for parameter mB
#    vB
#        [40] nan
# Insufficient data points for fitting.
# Failed to fit polynomial for parameter vB
#
# Making plot
# lr computing interceptions failed
# Error: cannot unpack non-iterable NoneType object
# Only one error determined
# Only one error determined
# Only one error determined
# /Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py:657: RankWarning: Polyfit may be poorly conditioned
#   coefs = [np.polyfit(x, y, deg=i) for i in range(1, max_degree+1)]
# /Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py:657: RankWarning: Polyfit may be poorly conditioned
#   coefs = [np.polyfit(x, y, deg=i) for i in range(1, max_degree+1)]
# /Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py:657: RankWarning: Polyfit may be poorly conditioned
#   coefs = [np.polyfit(x, y, deg=i) for i in range(1, max_degree+1)]
# /Users/villasenor/science/github/jvillasr/MINATO/minato/read_results.py:657: RankWarning: Polyfit may be poorly conditioned
#   coefs = [np.polyfit(x, y, deg=i) for i in range(1, max_degree+1)]

# %% [markdown]
# # 2D $\chi^2$ map

# %% [markdown]
# It can be useful to plot the 2D $\chi^2$ map to look for correlations and degeneracies.<br>
# For this we need to bring back the grid we constructed for the `span_example` tutorial, and we'll put it in a dictionary

# %%
teffA = np.linspace(10, 15, 6, dtype=int)
loggA = [20, 22, 24, 26, 28]
rotA = list(range(20, 70, 10))
teffB = [22, 24, 26, 28, 30, 32.5]
loggB = [25, 30, 35, 40]
# rotB = list(range(0, 600, 100))
rotB = [200]
lrat = np.linspace(30, 45, 4)/100
he2h = np.linspace(8, 12, 5)/100
pars_dic = {'lrat':lrat, 'He2H':he2h, 'rotB':rotB, 'loggB':loggB, 'teffB':teffB, 'rotA':rotA, 'loggA':loggA, 'teffA':teffA}

# %% [markdown]
# It's important to rename the $\chi^2$ column to 'chi2' so that the code can pick the correct column

# %%
df.rename(columns={'chi2_tot': 'chi2'}, inplace=True)

# %% [markdown]
# We'll do the plot using `plot_corr`. One of the parameters we'll use here is `rot_labels` to rotate the tick labels that are too long.<br> We need the number of the bottom panels where we want to apply the rotation, this number increases to the right and from top to bottom, so in our case we want panels 45 and 47.

# %% [markdown]
# The parameter `vmax` is also useful since it will allows to adapt the maximum value in the color map.<br>
# The histogram at the beginning of this tutorial can be helpful for this.

# %% [markdown]
# Setting `clabels='sigma'` will plot $\sigma$ labels to the contours. `clabels='numeric'` can also be used to show numeric values.

# %%
rotate = [45, 47]
rr.plot_corr(df, pars_dic, vmax=1.6, rot_labels=rotate, clabels='sigma')

# %% [markdown]
# To see how to plot the best-fitting models found in this tutorial, see the **plot_model** tutorial
